# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
school_count = len(school_data_complete["school_name"].unique())

# %%
student_count = len(school_data_complete["Student ID"].unique())

# %%
Total_budget = school_data_complete["budget"].unique().sum()

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %%
pd.DataFrame({"school_count": [school_count], "student_count": [student_count], "Total_budget": [Total_budget]})
# Out:
#    school_count  student_count  Total_budget
# 0            15          39170      24649428

# %%
ave_math = school_data_complete["math_score"].mean()

# %%
ave_read = school_data_complete["reading_score"].mean()

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
# % passing math: score of 70% or greater
math_approved_df = (school_data_complete.loc[school_data_complete['math_score'] >= 70].math_score.count()) / student_count * 100
math_approved_df
# Out:
# 74.9808526933878

# %%
# % passing reading: scores of 70% or greater
reading_approved_df = (school_data_complete.loc[school_data_complete['reading_score'] >= 70].reading_score.count()) / student_count * 100
reading_approved_df
# Out:
# 85.80546336482001

# %%
school_data_complete.to_excel("pycityschool.xls", sheet_name="Sheet1")

# %%
# % Overall Passing: students passing both math and reading 70% or higher
#student_count passing both math & reading
overall_pass_df = (reading_approved_df + math_approved_df) / 2

# %%
overall_pass_df
# Out:
# 80.39315802910392

# %%
#Create a Dataframe to hold the above results.Title: School Summary
District_Summary = District_Summary = pd.DataFrame({"Total Schools":[school_count], "Total Studens":[student_count], "Total Budget":[Total_budget], "Average Math Score":[ave_math], "Average Reading Score":[ave_read], "% Passing Math":[math_approved_df], "% Passing Reading":[reading_approved_df], "% Overall Passing Rate":[overall_pass_df]})

# %%
District_Summary
# Out:
#    Total Schools  Total Studens  Total Budget  Average Math Score  \
# 0             15          39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.393158

# %% [markdown]
# SCHOOL SUMMARY

# %% [markdown]
# ## * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_data = school_data_complete.set_index('school_name').groupby(["school_name"])

# %%
schooltype = school_data_complete.set_index("school_name")["type"]

# %%
student_count = len(school_data_complete["Student ID"].unique())

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
school_data_complete.budget.mean()
# Out:
# 2117240.989481746

# %%
school_data_complete.set_index("school_name")["budget"]/school_data_complete.set_index("school_name")["size"]
# Out:
# school_name
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
# Huang High School     655.0
#                       ...
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Thomas High School    638.0
# Length: 39170, dtype: float64

# %%
#avg_math = list(student_data.math_score.mean())
school_data_complete.set_index('school_name').groupby(["school_name", 'math_score'])
school_data_complete.head(20)
# Out:
#     Student ID       student_name gender grade        school_name  \
# 0            0       Paul Bradley      M   9th  Huang High School
# 1            1       Victor Smith      M  12th  Huang High School
# 2            2    Kevin Rodriguez      M  12th  Huang High School
# 3            3  Dr. Richard Scott      M  12th  Huang High School
# 4            4         Bonnie Ray      F   9th  Huang High School
# 5            5      Bryan Miranda      M   9th  Huang High School
# 6            6      Sheena Carter      F  11th  Huang High School
# 7            7       Nicole Baker      F  12th  Huang High School
# 8            8       Michael Roth      M  10th  Huang High School
# 9            9     Matthew Greene      M  10th  Huang High School
# 10          10   Andrew Alexander      M  10th  Huang High School
# 11          11      Daniel Cooper      M  10th  Huang High School
# 12          12    Brittney Walker      F   9th  Huang High School
# ...

# %%
#avg_read = list(student_data.reading_score.mean())
school_data_complete.reading_score.mean()
# Out:
# 81.87784018381414

# %%
#avg_math = list(student_data.math_score.mean())
school_data_complete.math_score.mean()
# Out:
# 78.98537145774827

# %%
School_Summary= school_data_complete = pd.DataFrame({"Total Schools":[school_count], "Total Studens":[student_count], "Total Budget":[Total_budget], "Average Math Score":[ave_math], "Average Reading Score":[ave_read], "% Passing Math":[math_approved_df], "% Passing Reading":[reading_approved_df], "% Overall Passing Rate":[overall_pass_df]})

# %%
School_Summary
# Out:
#    Total Schools  Total Studens  Total Budget  Average Math Score  \
# 0             15          39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  \
# 0               81.87784       74.980853          85.805463
#
#    % Overall Passing Rate
# 0               80.393158

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_count
# Out:
# 15

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.374684              83.864438       93.599695
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          96.790680          90.621535
# Large (2000-5000)           82.766634          58.286003

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Out:
# 39170
